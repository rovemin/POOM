# %% [markdown]
# <a href="https://colab.research.google.com/github/rovemin/POOM/blob/main/technology-verification/DogImageAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google Colab에 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# mtcnn 패키지와 Keras FaceNet 설치
# !pip install mtcnn
# !pip install keras-facenet

# 실행에 필요한 패키지 및 라이브러리 불러오기
import mtcnn
import matplotlib.pyplot as plt
from os import listdir
from PIL import Image
from numpy import asarray
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 7.6 MB/s
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn) (2.9.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn) (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-facenet
#   Downloading keras-facenet-0.3.2.tar.gz (10 kB)
# Requirement already satisfied: mtcnn in /usr/local/lib/python3.8/dist-packages (from keras-facenet) (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn->keras-facenet) (2.9.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from mtcnn->keras-facenet) (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-python>=4.1.0->mtcnn->keras-facenet) (1.21.6)
# Building wheels for collected packages: keras-facenet
#   Building wheel for keras-facenet (setup.py) ... done
#   Created wheel for keras-facenet: filename=keras_facenet-0.3.2-py3-none-any.whl size=10386 sha256=f20258f6ed11aa9c32210fddffe33dc6ed8abbbbdb18b61b9313b375ef066582
#   Stored in directory: /root/.cache/pip/wheels/dc/5f/3a/fa496ade459f1dcb2bdef3ad74cbdff2c90c28d09d6db39859
# Successfully built keras-facenet
# Installing collected packages: keras-facenet
# Successfully installed keras-facenet-0.3.2

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/1.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (173, 206, 3)
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 424ms/step
# {'box': [42, 25, 108, 134], 'confidence': 0.9798356890678406, 'keypoints': {'left_eye': (74, 79), 'right_eye': (114, 74), 'nose': (91, 96), 'mouth_left': (74, 120), 'mouth_right': (108, 118)}}
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 129ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/2.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (572, 676, 3)
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 5/5 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 142ms/step
# {'box': [228, 162, 236, 275], 'confidence': 0.9301125407218933, 'keypoints': {'left_eye': (289, 268), 'right_eye': (376, 259), 'nose': (321, 274), 'mouth_left': (296, 353), 'mouth_right': (375, 348)}}
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 5/5 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/3.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (198, 197, 3)
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 124ms/step
# WARNING:tensorflow:5 out of the last 26 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2658866af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 135ms/step
# {'box': [40, 23, 105, 132], 'confidence': 0.8042212724685669, 'keypoints': {'left_eye': (79, 70), 'right_eye': (120, 77), 'nose': (100, 80), 'mouth_left': (77, 114), 'mouth_right': (109, 121)}}
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/4.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (276, 304, 3)
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 137ms/step
# {'box': [60, 72, 127, 168], 'confidence': 0.9431986808776855, 'keypoints': {'left_eye': (112, 130), 'right_eye': (165, 137), 'nose': (140, 161), 'mouth_left': (106, 196), 'mouth_right': (150, 203)}}
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/5.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (376, 409, 3)
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 3/3 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 127ms/step
# {'box': [83, 68, 223, 279], 'confidence': 0.9137123227119446, 'keypoints': {'left_eye': (143, 166), 'right_eye': (249, 168), 'nose': (183, 207), 'mouth_left': (138, 272), 'mouth_right': (231, 276)}}
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 3/3 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/6.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (900, 506, 3)
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 131ms/step
# {'box': [159, 268, 192, 234], 'confidence': 0.8156602382659912, 'keypoints': {'left_eye': (219, 349), 'right_eye': (293, 349), 'nose': (258, 359), 'mouth_left': (226, 421), 'mouth_right': (288, 424)}}
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/7.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 664, 3)
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 3/3 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 141ms/step
# {'box': [169, 155, 193, 241], 'confidence': 0.7194678783416748, 'keypoints': {'left_eye': (224, 251), 'right_eye': (304, 238), 'nose': (263, 268), 'mouth_left': (239, 331), 'mouth_right': (305, 322)}}
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 3/3 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/8.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 680, 3)
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 125ms/step
# {'box': [219, 184, 344, 429], 'confidence': 0.8203279376029968, 'keypoints': {'left_eye': (278, 357), 'right_eye': (414, 344), 'nose': (330, 418), 'mouth_left': (298, 508), 'mouth_right': (417, 492)}}
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/9.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 680, 3)
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 6/6 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 123ms/step
# {'box': [242, 200, 184, 232], 'confidence': 0.8567733764648438, 'keypoints': {'left_eye': (304, 285), 'right_eye': (375, 288), 'nose': (340, 302), 'mouth_left': (306, 364), 'mouth_right': (366, 367)}}
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 6/6 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/10.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 680, 3)
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 5/5 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 149ms/step
# {'box': [209, 282, 145, 178], 'confidence': 0.7061097025871277, 'keypoints': {'left_eye': (241, 346), 'right_eye': (299, 345), 'nose': (264, 362), 'mouth_left': (251, 409), 'mouth_right': (293, 409)}}
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 5/5 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/11.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 680, 3)
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 130ms/step
# {'box': [185, 196, 321, 336], 'confidence': 0.7987717986106873, 'keypoints': {'left_eye': (305, 334), 'right_eye': (394, 329), 'nose': (351, 360), 'mouth_left': (306, 430), 'mouth_right': (378, 425)}}
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# 데이터셋에서 이미지 불러오기
filename = "/content/drive/MyDrive/dog-faces-dataset/training/004/12.jpg"
pixels = plt.imread(filename)
print("Shape of image/array:",pixels.shape)
imgplot = plt.imshow(pixels)
plt.show()

# 데이터셋에서 이미지 불러오기
image = Image.open(filename)
# 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
image = image.convert('RGB')
# 배열로 변환
pixels = asarray(image)

detector = MTCNN()

# 이미지에서 얼굴 탐지
results = detector.detect_faces(pixels)
for result in results:
    print(result)

# 탐지된 물체로 이미지 그리기
def draw_facebox(filename, result_list):
    data = plt.imread(filename)
    plt.imshow(data)
    ax = plt.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = plt.Circle(value, radius=10, color='red')
            ax.add_patch(dot)
        plt.show()

# 이미지에서 얼굴 영역 탐지하기
faces = detector.detect_faces(pixels)

# 원본 이미지에 탐지된 얼굴 영역 그리기
draw_facebox(filename, faces)
# Out:
# Shape of image/array: (680, 510, 3)
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 3/3 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 134ms/step
# {'box': [168, 165, 154, 192], 'confidence': 0.7418824434280396, 'keypoints': {'left_eye': (226, 239), 'right_eye': (286, 246), 'nose': (258, 261), 'mouth_left': (223, 307), 'mouth_right': (267, 312)}}
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 3/3 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# 주어진 사진에서 하나의 얼굴 추출
def extract_face(filename, required_size=(160, 160)):
  # 데이터셋에서 이미지 불러오기 - PIL 라이브러리와 open() 함수 이용하여 이미지를 넘파이 배열로 로드
  image = Image.open(filename)
  # 이미지에 알파 채널이 있거나 이미지가 흑백인 경우 등 필요 시 RGB로 변환
  image = image.convert('RGB')
  # 배열로 변환
  pixels = asarray(image)
  # 감지기 생성, 기본 가중치 이용
  detector = MTCNN()
  # 이미지에서 얼굴 감지
  results = detector.detect_faces(pixels)
  # 첫 번째 얼굴에서 경계 상자 추출
  x1, y1, width, height = results[0]['box']
  # 버그 수정
  x1, y1 = abs(x1), abs(y1)
  x2, y2 = x1 + width, y1 + height
  # 얼굴 추출
  face = pixels[y1:y2, x1:x2]
  # 모델 사이즈로 픽셀 재조정
  image = Image.fromarray(face)
  image = image.resize(required_size)
  face_array = asarray(image)
  return face_array

# 이미지 불러와서 얼굴 추출하기
pixels = extract_face('/content/drive/MyDrive/dog-faces-dataset/training/004/1.jpg')
plt.imshow(pixels)
plt.show()
print(pixels.shape)

# 폴더를 플롯으로 구체화하기
folder = '/content/drive/MyDrive/dog-faces-dataset/training/004/'
i = 1

# 파일 나열하기
for filename in listdir(folder):
  # 경로
  path = folder + filename
  # 얼굴 추출
  face = extract_face(path)
  print(i, face.shape)
  # 플롯
  pyplot.subplot(2, 6, i)
  pyplot.axis('off')
  pyplot.imshow(face)
  i += 1
pyplot.show()
# Out:
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 12ms/step
# WARNING:tensorflow:5 out of the last 25 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f264f682430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 155ms/step
# (160, 160, 3)
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1 (160, 160, 3)
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 151ms/step
# 2 (160, 160, 3)
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 3/3 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 137ms/step
# 3 (160, 160, 3)
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 129ms/step
# 4 (160, 160, 3)
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 121ms/step
# 5 (160, 160, 3)
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 5/5 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 133ms/step
# 6 (160, 160, 3)
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 3/3 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 143ms/step
# 7 (160, 160, 3)
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 6/6 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 132ms/step
# 8 (160, 160, 3)
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 10/10 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 125ms/step
# 9 (160, 160, 3)
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 5/5 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 128ms/step
# 10 (160, 160, 3)
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 134ms/step
# 11 (160, 160, 3)
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 3/3 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 129ms/step
# 12 (160, 160, 3)
